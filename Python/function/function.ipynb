# %%
def firstFunction():
    print("Hello world")

firstFunction()
# Out:
# Hello world

# %%
def add(a,b):
    sum=a+b
    return sum

add(10,20)
# Out:
# 30

# %%
print(add(10,20))
# Out:
# 30

# %%
x = 101 # Global scope

def func():
    x =102 # local scope
    print(x)

func()
print(x)
# Out:
# 102
# 101

# %%
# Default argument

def greet (name,message):
    print (name,message)

greet("Messi", "Hola")
# Out:
# Messi Hola

# %%
def greet (name,message = "Good Morning"):
    print(name,message)

greet("Messi")
# Out:
# Messi Good Morning

# %%
## Keyword arguments

def greet(name,age,message):
    print(message,name,"your age is",age)

greet("Deepak",22,"Hello")
# Out:
# Hello Deepak your age is 22

# %%
def greet(name,age,message):
    print(message,name,"your age is",age)

greet(22,"Deepak","Hello")
# Out:
# Hello 22 your age is Deepak
