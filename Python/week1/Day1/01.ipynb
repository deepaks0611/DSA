# %% [markdown]
# ##### Q1. Check Even or odd

# %%
num = int(input("Enter a number"))

if num % 2 == 0:
    print("This is even number")
else:
    print("This is odd number")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 num = int(input("Enter a number"))
#       3 if num % 2 == 0:
#       4     print("This is even number")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# #### Q2. Sum of first N Natural numbers

# %%
sum_n =0
n = int(input("Enter a number:"))
for i in range(1,n+1):
    sum_n = sum_n+i
print("Sum of first",n,"natural number is", sum_n)
# Out:
# Sum of first 49 natural number is 1225

# %% [markdown]
# #### Q3. Factorial of a number

# %%
n = 5
fact = 1
for i in range (1,n+1):
    fact = fact * i
print(fact)
# Out:
# 120

# %% [markdown]
# #### Q4. Check Prime Number

# %%
n = 13
if n > 1:
    for i in range (2,n):
        if n % i == 0 :
            print("Not a prime number")
            break
    else:
            print("Number is prime")
# Out:
# Number is prime

# %% [markdown]
# #### Q5. Greatest Common Divisor (GCD)
