# %% [markdown]
# #### Comment
#
# 1. Single line comment
# 2. Multi line comment

# %%
# This is a commented line -> single line comment

print("Hello")
# Out:
# Hello

# %%
'''
1st line of comment
2nd line of comment
3rd line of comment  
'''
# Out:
# '\n1st line of comment\n2nd line of comment\n3rd line of comment  \n'
