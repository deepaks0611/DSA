# %%
# Input()

name = input()
print(name)

# %%
age = input("please sir, enter age in years")
print(age)

# %%
# Output in the world of python

print ("I am Deepak")
# Out:
# I am Deepak

# %%
name = "Deepak"
age = 22

print ("Hello, my name is", name , "and my age is" , age)
# Out:
# Hello, my name is Deepak and my age is 22

# %% [markdown]
# #### Support for the formatted string

# %%
print (f" My name is {name} and age is {age}")
# Out:
#  My name is Deepak and age is 22

# %%
x = 2
y = 3
z = 4

print(x,y,z , sep = " ")
# Out:
# 2 3 4

# %%
print ("Hello") 
print ("World")
print ("!")
# Out:
# Hello
# World
# !

# %%
print ("Hello", end = " ") 
print ("World", end = " ")
print ("!")
# Out:
# Hello World !
