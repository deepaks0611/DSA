# %% [markdown]
# ##### if /elif
# - condition expression [boolean]-> True / False
# - Evaluate out to be boolean

# %% [markdown]
# ##### Truly value
# - sequence datatype -> non empyth -> True
# - Non zero numerical value -> 3,7 -> True

# %%
if [5] :
    print("Inside if")
# Out:
# Inside if

# %% [markdown]
# ##### Falsy value
# - sequence data type -> Empyt
# - Nimerical value which is 0

# %%
if 0 :
    print("Inside if")
else :
    print("Inside else")
# Out:
# Inside else

# %%
if "" :
    print("Inside if")
else :
    print("Inside else")
# Out:
# Inside else
