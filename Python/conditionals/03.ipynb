# %% [markdown]
# #### Nested Conditional

# %%
x  = 19

if x>5 :
    print("x is greater than 5")

    if x%2 == 0 :
        print("x is even")
    else :
        print("x is odd")
else :
    print("x is less than 5")
# Out:
# x is greater than 5
# x is odd
