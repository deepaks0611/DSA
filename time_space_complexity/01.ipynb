# %% [markdown]
# #### Time Complexity

# %%
def greet(n):
    i = 1
    while (i<n):
        print("Namaste")
        i = i + 1

greet(3)
# Out:
# Namaste
# Namaste

# %%
print("Hello")
# Out:
# Hello
